# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("dadosoficina05.txt")
df.head()
# Out:
#              city  area  rooms  bathroom  parking spaces floor     animal  \
# 0       São Paulo    70      2         1               1     7      acept
# 1    Porto Alegre    80      1         1               1     6      acept
# 2    Porto Alegre    51      2         1               0     2      acept
# 3       São Paulo    25      1         1               0     1  not acept
# 4  Rio de Janeiro    72      2         1               0     7      acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1000              2800                  0
# 2  not furnished       270              1112                 22
# 3  not furnished         0               800                 25
# 4  not furnished       740              1900                 85
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   41        3841
# ...

# %%
plt.figure(figsize=(20, 5))
plt.style.use('seaborn-pastel')
plt.title('Distribuição dos imóveis por valor do aluguel')
plt.hist(df['rent amount (R$)'], bins=20)
plt.show()

# %%
# A faixa de valores de aluguel mais comum é a primeira: entre 0 e R$2.500,00

# %%
plt.figure(figsize=(20, 10))
plt.style.use('seaborn-pastel')
plt.title('Distribuição dos imóveis por valor do aluguel')
sns.kdeplot(df['fire insurance (R$)'], shade=True)
plt.show()

# %%
# Valores acima de 50 reais são incomuns
